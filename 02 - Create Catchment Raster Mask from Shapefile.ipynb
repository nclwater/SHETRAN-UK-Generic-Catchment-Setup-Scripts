# %% [markdown]
# # Create Catchment Raster Mask from Shapefile
#
# This notebook can be used to create the catchment masks required for the _03 - SHETRAN UK Catchment Set Up Script_.
#
# These catchment masks can have any name, but are written in ascii format with the extents rounded to the nearest resolution unit (i.e. are no more precise than their resolution). This is so that the catchment masks align with the input datasets created in _01 - Build SHETRAN Input Datasets_ notebook.
#
# The following error is most likely caused by an issue with your environment and Geopandas - this can be fixed by switching to a different environment or python idle...
# *DataDirError: Valid PROJ data directory not found. Either set the path using the environmental variable PROJ_LIB or with `pyproj.datadir.set_data_dir`.*

# %%
# import sys
# sys.path.append("I:/SHETRAN_GB_2021/01_Scripts/SHETRAN_UK_Generic_Catchment_Setup_Scripts/")
import Functions_Model_Set_Up as SHETRAN_Setup

resolution = 200
catchment = "80005"

SHETRAN_Setup.create_catchment_mask_from_shapefile(
    shapefile_path=f"I:/SHETRAN_GB_2021/02_Input_Data/NRFA Catchment Outlines/Shapefiles/nrfa_{catchment}.zip",
    output_ascii_path=f"I:/SHETRAN_GB_2021/02_Input_Data/NRFA Catchment Outlines/Rasters/{resolution}m/{catchment}.txt",
    resolution=resolution, NA_value=-9999, fix_holes=True)
# Out:
# C:\ProgramData\anaconda3\envs\SHETRAN_UK\lib\site-packages\pyproj\__init__.py:73: UserWarning: Valid PROJ data directory not found. Either set the path using the environmental variable PROJ_LIB or with `pyproj.datadir.set_data_dir`.
#   warnings.warn(str(err))
# PROJ: proj_create_from_database: Cannot find proj.db
# ---------------------------------------------------------------------------
# DataDirError                              Traceback (most recent call last)
# Cell In[1], line 8
#       5 resolution = 200
#       6 catchment = "80005"
# ----> 8 SHETRAN_Setup.create_catchment_mask_from_shapefile(
#       9     shapefile_path=f"I:/SHETRAN_GB_2021/02_Input_Data/NRFA Catchment Outlines/Shapefiles/nrfa_{catchment}.zip",
#      10     output_ascii_path=f"I:/SHETRAN_GB_2021/02_Input_Data/NRFA Catchment Outlines/Rasters/{resolution}m/{catchment}.txt",
#      11     resolution=resolution, NA_value=-9999, fix_holes=True)
#
# ...
